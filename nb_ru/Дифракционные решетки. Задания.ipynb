# %% [markdown]
# Лицензия MIT
#
# © Алексей Александрович Щербаков, 2024

# %% [markdown]
# # Дифракционные решетки. Задания

# %% [markdown]
# ## Общие задания
#
# 1. С помощью Фурье-модального методов постройте зависимость числа Фурье-гармоник от глубины, толщины и контраста одномерной дифракционной решетки, которое бы обеспечивало расчёты с точностью порядка 0.1% для эффективностей всех распространяющихся дифракционных порядков. В качестве решетки рассмотрите плоский срез одномерного кристалла, состоящего из чередующихся слоев воздуха и диэлектрика. Рассмотрите диапазон изменения контраста 0.1-10, диапазон периодов 0.1-10 длин волн, диапазон глубин 0.1-10 длин волн.
# 2. Рассмотрите простую решетку, представляющую собой плоский срез одномерного кристалла, состоящего из чередующихся слоев воздуха и диэлектрика с показателем преломления 3.5 и коэффициентом заполнения 0.5. Рассчитайте карту отражения в координатах $(k_B\Lambda/2\pi,\;\Lambda/\lambda)$ для отношения глубины решетки к периоду, равного 0.7. Продемонстрируйте проявления мод Фабри-Перо и высокодобротных резонансов. Укажите положения связанных состояний в континууме. Постройте аналогичную карту в координатах $(h/\lambda,\;\Lambda/\lambda)$ для Г-точки и для малого ненулевого блоховского вектора. Объясните разницу в полученных картинах. Как с помощью данного графика можно спроектировать решетки с высокодобротными резонансами?
# 3. Высокодобротные резонансы на диэлектрических решетках используются для оптического детектирования биохимических примесей в водных растворах (показатель преломления 1.33). В качестве примера рассмотрим структуру, представляющую собой стеклянную подложку (показатель преломления 1.49) с нанесенным слоем оксида гафния (показатель преломления 2.12) толщиной 86 нм, в котором вытравлена бинарная решетка с заполнением 0.5 на глубину 30 нм. Период решетки 339 нм. На длине волны 780 нм падающая из подложки плоская волна под углом 30 градусов возбудает первую ТЕ моду, так что в зависимости коэффициента отражения от угла падения в районе условия возбуждения моды наблюдается узкий резонансный пик с максимумом отражения в районе 100%. Постройте на комплексной плоскости окружность коэффициента отражения в районе пика резонансного отражения при измении угла падения. С помощью приближенных формул найдите постоянные $\alpha$ и $\beta$, определяющие распространение моды, с помощью проекций $k_x$, соответствующих максимальному и минимальноу коэффициенту отражения. Найдите полюс матрицы рассеяния с помощью одного из методов, рассмотренных в соответствующей лекции и сравните с полученными выше.

# %% [markdown]
# ## Инженерный трек
#
# 4. Для перенаправления лазерных пучков используются так называемые решетки с блеском, представляющие собой периодически нарезанную поверхность, часто с профилем, представляющим собой прямогульный треугольник, одна сторона которого много меньше другой, а период решетки много больше длины волны. Работа такой решетки заключается в перенаправлении энергии излучения в направлении, которое задаётся законом отражения для длинной стороны треугольника. Выведите условие, при котором это направление совпадает с $n$-м дифракционным порядком для заданного угла падения $\theta_{inc}$. Рассмотрите такую решетку из материала с показателем преломления 1.5. Пусть угол падения $\theta_{inc}=10^{\circ}$, а отраженный луч должен быть направлен в направлении, определяемом углом $\theta=30^{\circ}$. Какие могут быть периоды такой решетки и в каких порядках при этом будет наблюдаться требуемый зеркально отраженный от длинной грани луч? Рассчитайте зависимость энергии в отраженном луче от допустимого периода.
# 5. Для сжатия лазерных импульсов используются дифракционные решетки, перенаправляющие энергию излучения в -1 порядок дифракции. Одним из примеров может служить простая бинарная решетка, нанесенная на Брэгговское зеркало из чередующихся четвертьволновых пластин (многослойную подложку). Пусть требуется перенаправить энергию плоской волны с длиной 800 нм, падающую на структуру под углом 60 градусов. Структура представляет собой металлическое серебряное зеркало (диэлектрическая проницаемость -33) с нанесенным на нее слоем оксида алюминия (показатель преломления 1.62) толщиной 41 нм. Сверху нанесены прямоугольные штрихи решетки из оксида тантала (показатель преломления 2.21) шириной 214 нм. Подберите оптимальные период и глубину решетки, так чтобы в воздухе распространялись только нулевой и минус первый порядки дифракции, которые бы обеспечили максимальную перекачку энергии падающего пучка в -1 порядок дифракции.

# %% [markdown]
# ## Вычислительный трек
#
# 4. Изучите свойства решений дисперсионного уравнения для одномерного фотонного кристалла, состоящего из чередующихся поглощающих и диэлектрических слоёв, добавляя мнимую часть к диэлектрической проницаемости и строя траектории решений дисперсионного уравнения на комплексной плоскости. Предложите алгоритм для расчета констант распространения мод в таком кристалле и сравните результаты расчетов с константами распространения, полученными в рамках Фурье-модального метода.
# 5. Для решеток из второго общего задания выберите моду, для которой наблюдается как ССК, защищенное симметрией, так и интерференционное ССК. Напишите программу для расчета положения и добротности этой моды в зависимости от положения в зоне Бриллюэна. По какому закону растет добротность вблизи ССК?

# %% [markdown]
# ## Теоретический трек
#
# 4. В случае комплексной диэлектрической проницаемости дифференциальный оператор уравнения Гельмгольца для одномерного фотонного кристалла не является самосопряженным, следовательно, его собственные функции не ортогональны. Для применения модального метода необходимо иметь базис, ортогональный базису собственных значений указанного оператора. Учитывая явный вид внутреннего скалярного произведения $$ \langle f,g \rangle = \intop_0^{\Lambda} \frac{1}{\eta(x)} f^*(x) g(x) dx $$ запишите в явном виде оператор, сопряженный указанному. Покажите, что собственные функци исходного и сопряженного оперторов взаимно ортогональны. Какие изменения необходимо внести в модальный метод расчета матрицы рассеяния простой бинарной решетке с поглощающими материалами?
# 5. Получите соотношение между усеченными Фурье-образами электрической индукции и поля для ТМ поляризации для расчета дифракции на тонком слое скошенной под углом $\varphi$ бинарной решетки методом ФММ, приняв во внимание граничные условия на нормальные и тангенциальные компоненты электрического поля и следующие правила факторизации: усеченный Фурье-образ произведения непрерывной функции $f$ и функции $g$, имеющей разрывы первого рода, рассчитывается как произведение соотетствующих Теплицевой матрицы и вектора Фурье амплитуд $T(f)\boldsymbol{g}$; усеченный Фурье-образ произведения функций $f$ и $g$, имеющих совпадающие разрывы первого рода, рассчитывается как произведение соотетствующих обратной Теплицевой матрицы и вектора Фурье амплитуд $T^{-1}(1/f)\boldsymbol{g}$.
